# %%
import numpy as np
import matplotlib.pyplot as plt
import glob
import pandas as pd
import scipy as sp

# %%
names = glob.glob('/media/bill/Seagate1/alldatasets/arrays_dec/*')

# %%
names = names + glob.glob('/media/bill/Seagate1/alldatasets/missing_arrays/rspA*rep')

# %%
for n in names:
    tempdf = pd.io.parsers.read_csv(n,delim_whitespace=True)
    temparr = np.array(tempdf[['val_A','val_C','val_G','val_T']])
    maximum = np.max(np.abs(temparr))
    fig,ax = plt.subplots(figsize=((10,2)))
    plt.imshow(temparr.T,aspect='auto',interpolation='nearest',cmap='coolwarm',vmin=-maximum,vmax=maximum)
    plt.colorbar()
    plt.savefig(n+'_array',format='eps')
# Out:
# /media/bill/Seagate1/alldatasets/arrays_dec/minC_arabinose_38_56
# []
# /media/bill/Seagate1/alldatasets/arrays_dec/dinJ_LB_119_136
# []
# /media/bill/Seagate1/alldatasets/arrays_dec/yecE_heat_119_139
# []
# /media/bill/Seagate1/alldatasets/arrays_dec/cra_Anaero_35_51
# []
# /media/bill/Seagate1/alldatasets/arrays_dec/thrLABC_Anaero_56_75
# ['/media/bill/Seagate1/alldatasets/arrays_dec/thrLABC_Anaero_56_75logofindbeta.txt']
# /media/bill/Seagate1/alldatasets/arrays_dec/ybeZ_Anaero_13_29
# []
# /media/bill/Seagate1/alldatasets/arrays_dec/yedJ_Anaero_48_85
# ['/media/bill/Seagate1/alldatasets/arrays_dec/yedJ_Anaero_48_85logofindbeta.txt']
# /media/bill/Seagate1/alldatasets/arrays_dec/mscL_metal_54_71
# []
# /media/bill/Seagate1/alldatasets/arrays_dec/idnK_Anaero_25_49
# []
# /media/bill/Seagate1/alldatasets/arrays_dec/ybeZ_Anaero_57_76
# []
# /media/bill/Seagate1/alldatasets/arrays_dec/asnA_Tre_10_28
# []
# /media/bill/Seagate1/alldatasets/arrays_dec/araC_Anaero_0_23
# []
# /media/bill/Seagate1/alldatasets/arrays_dec/ydjA_Fe_103_120
# []
# /media/bill/Seagate1/alldatasets/arrays_dec/ycgB_heat_67_85
# []
# /media/bill/Seagate1/alldatasets/arrays_dec/eco_heat_92_125
# []
# /media/bill/Seagate1/alldatasets/arrays_dec/pcm_metal_38_56
# []
# /media/bill/Seagate1/alldatasets/arrays_dec/araC_Anaero_24_55
# []
# /media/bill/Seagate1/alldatasets/arrays_dec/yedJ_Anaero_12_32
# ['/media/bill/Seagate1/alldatasets/arrays_dec/yedJ_Anaero_12_32logofindbeta.txt']
# /media/bill/Seagate1/alldatasets/arrays_dec/ybiO_Fe_38_54
# []
# /media/bill/Seagate1/alldatasets/arrays_dec/asnA_heat_32_49
# ['/media/bill/Seagate1/alldatasets/arrays_dec/asnA_heat_32_49logofindbeta.txt']
# /media/bill/Seagate1/alldatasets/arrays_dec/bdcR_Fe_125_142
# []
# /home/bill/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:12: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   if sys.path[0] == '':
# /media/bill/Seagate1/alldatasets/arrays_dec/thiM_Anaero_26_45
# []
# /media/bill/Seagate1/alldatasets/arrays_dec/dinJ_xylara_21_50
# []
# /media/bill/Seagate1/alldatasets/arrays_dec/ilvC_xylara_38_54
# ['/media/bill/Seagate1/alldatasets/arrays_dec/ilvC_xylara_38_54logofindbeta.txt']
# /media/bill/Seagate1/alldatasets/arrays_dec/aegA_xylara_107_125
# []
# /media/bill/Seagate1/alldatasets/arrays_dec/mscM_Fe_37_63
# []
# /media/bill/Seagate1/alldatasets/arrays_dec/eco_heat_56_72
# ['/media/bill/Seagate1/alldatasets/arrays_dec/eco_heat_56_72logofindbeta.txt']
# /media/bill/Seagate1/alldatasets/arrays_dec/dinJ_xylara_83_99
# ['/media/bill/Seagate1/alldatasets/arrays_dec/dinJ_xylara_83_99logofindbeta.txt']

# %%
tempdf = pd.io.parsers.read_csv('/media/bill/Seagate1/alldatasets/logos_for_manu/bdcR_arabinose_87_101',delim_whitespace=True)
temparr = np.array(tempdf[['val_A','val_C','val_G','val_T']])

# %%
def fix_matrix_gauge(emat):
    """Fix gauge of an energy matrix such that the minimum value
    of each column is zero (columns correspond to positions), and
    overall matrix norm is equal to 1."""
    # fix mean
    for j in range(emat.shape[1]):
        emat[:,j] = emat[:,j] -sp.mean(emat[:,j])
    # fix sum of variances equal to length of matrix
    svar = np.sum(np.var(emat,axis=0))
    emat = sp.sqrt(emat.shape[1])*emat/sp.sqrt(svar)
    return emat

def fix_matrix_gauge_df(df,inv_dict):
    labels = ['val_' + str(inv_dict[i]) for i in range(len(inv_dict))]
    #fix max and then subtract and negate (to give energy matrix representation)
    df_max = df[labels].max(axis=1)
    df[labels] = -1*df[labels].subtract(df_max,axis='index')
    #fix sum of variances
    product = np.sqrt(np.sum(np.sum(df[labels]*df[labels])))
    df[labels] = df[labels]/product
    return df

def RandEmat(L,Ldict):
    '''Makes 4xL random emat'''
    emat_0 = fix_matrix_gauge(sp.randn(Ldict,L))
    return emat_0

# %%
temparr = RandEmat(14,4).T

# %%
fig,ax = plt.subplots(figsize=((10,2)))
plt.imshow(temparr.T,aspect='auto',interpolation='nearest',cmap='coolwarm',vmin=-2,vmax=2)
plt.colorbar()
plt.savefig('/media/bill/Seagate1/bdcR_random'+'_array.eps',format='eps')
