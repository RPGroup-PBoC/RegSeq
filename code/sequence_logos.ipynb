# %%
import logomaker
import matplotlib.pyplot as plt

# %% [markdown]
# After loading the requisite modules (logomaker and matplotlib), let's take a look at a sequence logo _example_ for CRP. This sequence logo is Figure 1B in the paper by [Tareen and Kinney, 2020](https://academic.oup.com/bioinformatics/article/36/7/2272/5671693).

# %%
# load crp energy matrix
crp_df = -logomaker.get_example_matrix('crp_energy_matrix',
                                        print_description=False)

# create Logo object
crp_logo = logomaker.Logo(crp_df,
                          shade_below=.5,
                          fade_below=.5,
                          font_name='Arial Rounded MT Bold')

# style using Logo methods
crp_logo.style_spines(visible=False)
crp_logo.style_spines(spines=['left', 'bottom'], visible=True)
crp_logo.style_xticks(rotation=90, fmt='%d', anchor=0)

# style using Axes methods
crp_logo.ax.set_ylabel("$-\Delta \Delta G$ (kcal/mol)", labelpad=-1)
crp_logo.ax.xaxis.set_ticks_position('none')
crp_logo.ax.xaxis.set_tick_params(pad=-1)
