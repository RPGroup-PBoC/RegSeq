# %%
import pandas as pd
import glob
import numpy as np

# %%
names = glob.glob('*smooth*')

# %%
names
# Out:
# ['leuABCDarabinosedataset_alldone_with_largeMCMC194infoshift_smoothv2',
#  'rspAarabinosedataset_alldone_with_largeinfoshift_smoothv2',
#  'maoPhdfRdataset_alldone_with_largeMCMC195_infoshift_no_weightv2_smoothed.txt',
#  'yjjJM9dataset_alldone_with_largeMCMC194_infoshift_no_weightv2_smoothed.txt',
#  'yjjJSSdataset_alldone_with_largeMCMC194infoshift_smoothv2',
#  'maoPLBdataset_alldone_with_largeMCMC195_infoshift_no_weightv2_smoothed.txt',
#  'aphAAnaerodataset_alldone_with_largeMCMC194_infoshift_no_weightv2_smoothed.txt',
#  'idnKarabinosedataset_alldone_with_largeMCMC194infoshift_smoothv2']

# %%
def sliding_window(y,windowsize=3):
    out_vec = np.zeros_like(y)
    for i in range(len(y)-windowsize):
        out_vec[i] = np.sum(y[i:i+windowsize])/windowsize
    return out_vec

# %%
infodf = pd.DataFrame()
infodf['pos'] = range(1,158)

# %%
possible_growths = ['arabinose','hdfR','M9','SS','LB','Anaero']

# %%
for i,name in enumerate(names):
    tempdf = pd.io.parsers.read_csv(name,delim_whitespace=True)
    for x in possible_growths:
        if x in name:
            gene = name.split(x)[0]
            growth = x
    if growth == 'arabinose':
        tempdf['info'] = sliding_window(tempdf['info'])
    infodf[gene + '_' + growth + '_info'] = tempdf['info']

# %%
infodf
# Out:
#      pos  leuABCD_arabinose_info  rspA_arabinose_info  maoP_hdfR_info  \
# 0      1                0.000008            -0.000055       -0.000176
# 1      2               -0.000050            -0.000051       -0.000262
# 2      3               -0.000053            -0.000061       -0.000093
# 3      4               -0.000085            -0.000063       -0.000022
# 4      5               -0.000046            -0.000129       -0.000057
# ..   ...                     ...                  ...             ...
# 152  153               -0.000056            -0.000008       -0.000103
# 153  154               -0.000056            -0.000053       -0.000172
# 154  155                0.000013            -0.000058       -0.000121
# 155  156                0.000051            -0.000058       -0.000023
# 156  157                0.000045            -0.000067       -0.000214
#
#      yjjJ_M9_info  yjjJ_SS_info  maoP_LB_info  aphA_Anaero_info  \
# 0       -0.000004     -0.000012     -0.000234          0.000001
# 1       -0.000012     -0.000072     -0.000248          0.000023
# 2       -0.000013     -0.000009     -0.000076          0.000012
# 3       -0.000009     -0.000010      0.000014         -0.000006
# 4       -0.000004     -0.000088      0.000010         -0.000168
# ..            ...           ...           ...               ...
# 152      0.000119      0.000441     -0.000079          0.000002
# 153      0.000037      0.000061     -0.000114         -0.000052
# 154      0.000087      0.000117     -0.000152          0.000015
# 155      0.000099      0.000205      0.000135          0.000011
# 156      0.000045      0.000134      0.000179         -0.000001
#
#      idnK_arabinose_info
# 0              -0.000040
# 1              -0.000022
# 2              -0.000023
# 3              -0.000020
# 4              -0.000016
# ..                   ...
# 152            -0.000036
# 153             0.000083
# 154             0.000095
# 155             0.000091
# 156            -0.000004
#
# [157 rows x 9 columns]

# %%
infodf.to_csv('infomation_fig3.csv')
