# %%
#import basic modules
import glob
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy as sp
import peak_utils
import regseq.find_region as find_region

# %% [markdown]
# We will now load in all models so we can check which parts are significant. Only an example subset is stored on the github repo. You can download this data from the github repo or as a .tar.gz file from the website under the datasets section.

# %%
allnames = glob.glob('/home/bill/next100genes/scaled/*.txt')

# %%
allnames
# Out:
# ['/home/bill/next100genes/scaled/xapABLBdataset_alldone_with_largeMCMC194_infoshift_no_weightv13_nosmooth.txt',
#  '/home/bill/next100genes/scaled/yagHAnaerodataset_alldone_with_largeMCMC194_infoshift_no_weightv15_smoothed.txt',
#  '/home/bill/next100genes/scaled/xapABTredataset_alldone_with_largeMCMC194_infoshift_no_weightv15_smoothed.txt',
#  '/home/bill/next100genes/scaled/hicBxylaradataset_alldone_with_largeMCMC195_infoshift_no_weightv13_nosmooth.txt',
#  '/home/bill/next100genes/scaled/ydhOheatdataset_alldone_with_largeMCMC195_infoshift_no_weightv13_nosmooth.txt',
#  '/home/bill/next100genes/scaled/hicBmetaldataset_alldone_with_largeMCMC194_infoshift_no_weightv13_nosmooth.txt',
#  '/home/bill/next100genes/scaled/hicBxanth2dataset_alldone_with_largeMCMC195_infoshift_no_weightv15_smoothed.txt',
#  '/home/bill/next100genes/scaled/hicBLBdataset_alldone_with_largeMCMC194_infoshift_no_weightv13_nosmooth.txt',
#  '/home/bill/next100genes/scaled/hicBM9dataset_alldone_with_largeMCMC195_infoshift_no_weightv15_smoothed.txt',
#  '/home/bill/next100genes/scaled/xapABheatdataset_alldone_with_largeMCMC195_infoshift_no_weightv15_smoothed.txt',
#  '/home/bill/next100genes/scaled/hicBmetaldataset_alldone_with_largeMCMC195_infoshift_no_weightv15_smoothed.txt',
#  '/home/bill/next100genes/scaled/yagHarabinosedataset_alldone_with_largeMCMC194_infoshift_no_weightv13_nosmooth.txt',
#  '/home/bill/next100genes/scaled/xapABheatdataset_alldone_with_largeMCMC195_infoshift_no_weightv13_nosmooth.txt',
#  '/home/bill/next100genes/scaled/rumBAnaerodataset_alldone_with_largeMCMC194_infoshift_no_weightv15_smoothed.txt',
#  '/home/bill/next100genes/scaled/xapABM9dataset_alldone_with_largeMCMC194_infoshift_no_weightv13_nosmooth.txt',
#  '/home/bill/next100genes/scaled/ecoM9dataset_alldone_with_largeMCMC195_infoshift_no_weightv13_nosmooth.txt',
#  '/home/bill/next100genes/scaled/xapABAnaerodataset_alldone_with_largeMCMC194_infoshift_no_weightv13_nosmooth.txt',
#  '/home/bill/next100genes/scaled/ydhOM9dataset_alldone_with_largeMCMC194_infoshift_no_weightv15_smoothed.txt',
#  '/home/bill/next100genes/scaled/tigM9dataset_alldone_with_largeMCMC194_infoshift_no_weightv13_nosmooth.txt',
#  '/home/bill/next100genes/scaled/yagHAnaerodataset_alldone_with_largeMCMC195_infoshift_no_weightv13_nosmooth.txt',
#  '/home/bill/next100genes/scaled/tigM9dataset_alldone_with_largeMCMC194_infoshift_no_weightv15_smoothed.txt',
#  '/home/bill/next100genes/scaled/ecoheatdataset_alldone_with_largeMCMC194_infoshift_no_weightv13_nosmooth.txt',
#  '/home/bill/next100genes/scaled/ydhOheatdataset_alldone_with_largeMCMC195_infoshift_no_weightv15_smoothed.txt',
#  '/home/bill/next100genes/scaled/xapABheatdataset_alldone_with_largeMCMC194_infoshift_no_weightv13_nosmooth.txt',
#  '/home/bill/next100genes/scaled/ydhOAnaerodataset_alldone_with_largeMCMC195_infoshift_no_weightv13_nosmooth.txt',
#  '/home/bill/next100genes/scaled/ecoFedataset_alldone_with_largeMCMC194_infoshift_no_weightv15_smoothed.txt',
#  '/home/bill/next100genes/scaled/yagHLBdataset_alldone_with_largeMCMC195_infoshift_no_weightv13_nosmooth.txt',
#  '/home/bill/next100genes/scaled/ecoLBdataset_alldone_with_largeMCMC194_infoshift_no_weightv13_nosmooth.txt',
#  '/home/bill/next100genes/scaled/ecoAnaerodataset_alldone_with_largeMCMC194_infoshift_no_weightv15_smoothed.txt',
#  '/home/bill/next100genes/scaled/yagHarabinosedataset_alldone_with_largeMCMC195_infoshift_no_weightv13_nosmooth.txt',
#  '/home/bill/next100genes/scaled/xapABTredataset_alldone_with_largeMCMC195_infoshift_no_weightv13_nosmooth.txt',
#  '/home/bill/next100genes/scaled/xapAB0cAMPdataset_alldone_with_largeMCMC194_infoshift_no_weightv15_smoothed.txt',
#  '/home/bill/next100genes/scaled/ecometaldataset_alldone_with_largeMCMC194_infoshift_no_weightv13_nosmooth.txt',
#  '/home/bill/next100genes/scaled/tigM9dataset_alldone_with_largeMCMC195_infoshift_no_weightv13_nosmooth.txt',
#  '/home/bill/next100genes/scaled/yagHAnaerodataset_alldone_with_largeMCMC194_infoshift_no_weightv13_nosmooth.txt',
#  '/home/bill/next100genes/scaled/xapABarabinosedataset_alldone_with_largeMCMC195_infoshift_no_weightv13_nosmooth.txt',
#  '/home/bill/next100genes/scaled/yagHM9dataset_alldone_with_largeMCMC195_infoshift_no_weightv15_smoothed.txt',
#  '/home/bill/next100genes/scaled/ydhOAnaerodataset_alldone_with_largeMCMC194_infoshift_no_weightv13_nosmooth.txt',
#  '/home/bill/next100genes/scaled/tigM9dataset_alldone_with_largeMCMC195_infoshift_no_weightv15_smoothed.txt',
#  '/home/bill/next100genes/scaled/hicBheatdataset_alldone_with_largeMCMC195_infoshift_no_weightv15_smoothed.txt',
#  '/home/bill/next100genes/scaled/ecoarabinosedataset_alldone_with_largeMCMC194_infoshift_no_weightv15_smoothed.txt',
#  '/home/bill/next100genes/scaled/ecoAnaerodataset_alldone_with_largeMCMC194_infoshift_no_weightv13_nosmooth.txt',
#  '/home/bill/next100genes/scaled/hicBLBdataset_alldone_with_largeMCMC195_infoshift_no_weightv13_nosmooth.txt',
#  '/home/bill/next100genes/scaled/ecometaldataset_alldone_with_largeMCMC194_infoshift_no_weightv15_smoothed.txt',
#  '/home/bill/next100genes/scaled/ecoM9dataset_alldone_with_largeMCMC194_infoshift_no_weightv15_smoothed.txt',
#  '/home/bill/next100genes/scaled/ecoheatdataset_alldone_with_largeMCMC194_infoshift_no_weightv15_smoothed.txt',
#  '/home/bill/next100genes/scaled/ydhOLBdataset_alldone_with_largeMCMC195_infoshift_no_weightv15_smoothed.txt',
#  '/home/bill/next100genes/scaled/hicBheatdataset_alldone_with_largeMCMC194_infoshift_no_weightv13_nosmooth.txt',
#  '/home/bill/next100genes/scaled/ecoxylaradataset_alldone_with_largeMCMC194_infoshift_no_weightv13_nosmooth.txt',
#  '/home/bill/next100genes/scaled/yagHheatdataset_alldone_with_largeMCMC195_infoshift_no_weightv15_smoothed.txt',
#  '/home/bill/next100genes/scaled/xapABSSdataset_alldone_with_largeMCMC195_infoshift_no_weightv13_nosmooth.txt',
#  '/home/bill/next100genes/scaled/xapABSSdataset_alldone_with_largeMCMC194_infoshift_no_weightv13_nosmooth.txt',
#  '/home/bill/next100genes/scaled/hicBTredataset_alldone_with_largeMCMC195_infoshift_no_weightv15_smoothed.txt',
#  '/home/bill/next100genes/scaled/ecoheatdataset_alldone_with_largeMCMC195_infoshift_no_weightv15_smoothed.txt',
#  '/home/bill/next100genes/scaled/ecoSSdataset_alldone_with_largeMCMC194_infoshift_no_weightv15_smoothed.txt',
#  '/home/bill/next100genes/scaled/hicBTredataset_alldone_with_largeMCMC194_infoshift_no_weightv13_nosmooth.txt',
#  '/home/bill/next100genes/scaled/xapABSSdataset_alldone_with_largeMCMC194_infoshift_no_weightv15_smoothed.txt',
#  '/home/bill/next100genes/scaled/hicBxanth2dataset_alldone_with_largeMCMC194_infoshift_no_weightv13_nosmooth.txt',
#  '/home/bill/next100genes/scaled/ecoxylaradataset_alldone_with_largeMCMC194_infoshift_no_weightv15_smoothed.txt',
#  '/home/bill/next100genes/scaled/xapABLBdataset_alldone_with_largeMCMC195_infoshift_no_weightv13_nosmooth.txt',
#  '/home/bill/next100genes/scaled/rumBAnaerodataset_alldone_with_largeMCMC195_infoshift_no_weightv13_nosmooth.txt',
#  '/home/bill/next100genes/scaled/amiCdataset_5759_RNA41_with_tagv3_0_160MCMC194_infoshift_no_weightv13_nosmooth.txt',
#  '/home/bill/next100genes/scaled/ecoFedataset_alldone_with_largeMCMC194_infoshift_no_weightv13_nosmooth.txt',
#  '/home/bill/next100genes/scaled/relM9dataset_5760_RNA40_with_tagv3_0_160_MCMC194_infoshift_no_weightv15_smoothed.txt',
#  '/home/bill/next100genes/scaled/hicBmetaldataset_alldone_with_largeMCMC195_infoshift_no_weightv13_nosmooth.txt',
#  '/home/bill/next100genes/scaled/hicB0cAMPdataset_alldone_with_largeMCMC194_infoshift_no_weightv15_smoothed.txt',
#  '/home/bill/next100genes/scaled/phnAdataset_5760_RNA40_with_tagv3_0_160MCMC203_infoshift_no_weightv15_smoothed.txt',
#  '/home/bill/next100genes/scaled/rhledataset_5760_RNA40_with_tagv3_0_160_MCMC194_infoshift_no_weightv13_nosmooth.txt',
#  '/home/bill/next100genes/scaled/dgoRLB_MCMC_194_infoshift_no_weightv13_nosmooth.txt',
#  '/home/bill/next100genes/scaled/tigheatdataset_alldone_with_largeMCMC195_infoshift_no_weightv15_smoothed.txt',
#  '/home/bill/next100genes/scaled/ydhOM9dataset_alldone_with_largeMCMC195_infoshift_no_weightv13_nosmooth.txt',
#  '/home/bill/next100genes/scaled/hicBxanth2dataset_alldone_with_largeMCMC195_infoshift_no_weightv13_nosmooth.txt',
#  '/home/bill/next100genes/scaled/xapABSSdataset_alldone_with_largeMCMC195_infoshift_no_weightv15_smoothed.txt',
#  '/home/bill/next100genes/scaled/yagHheatdataset_alldone_with_largeMCMC195_infoshift_no_weightv13_nosmooth.txt',
#  '/home/bill/next100genes/scaled/xapABM9dataset_alldone_with_largeMCMC195_infoshift_no_weightv13_nosmooth.txt',
#  '/home/bill/next100genes/scaled/hicBheatdataset_alldone_with_largeMCMC195_infoshift_no_weightv13_nosmooth.txt',
#  '/home/bill/next100genes/scaled/ecoxanth2dataset_alldone_with_largeMCMC194_infoshift_no_weightv13_nosmooth.txt',
#  '/home/bill/next100genes/scaled/ecoAnaerodataset_alldone_with_largeMCMC195_infoshift_no_weightv13_nosmooth.txt',
#  '/home/bill/next100genes/scaled/ybjXLBdataset_5759_RNA41_with_tagv3_0_160_MCMC194_infoshift_no_weightv13_nosmooth.txt',
#  '/home/bill/next100genes/scaled/ecoarabinosedataset_alldone_with_largeMCMC194_infoshift_no_weightv13_nosmooth.txt',
#  '/home/bill/next100genes/scaled/phnAdataset_5760_RNA40_with_tagv3_0_160MCMC203_infoshift_no_weightv16_smoothed.txt',
#  '/home/bill/next100genes/scaled/hicBTredataset_alldone_with_largeMCMC195_infoshift_no_weightv13_nosmooth.txt',
#  '/home/bill/next100genes/scaled/xapABTredataset_alldone_with_largeMCMC195_infoshift_no_weightv15_smoothed.txt',
#  '/home/bill/next100genes/scaled/hicBTredataset_alldone_with_largeMCMC194_infoshift_no_weightv15_smoothed.txt',
#  '/home/bill/next100genes/scaled/ydhOLBdataset_alldone_with_largeMCMC195_infoshift_no_weightv13_nosmooth.txt',
#  '/home/bill/next100genes/scaled/xapAB0cAMPdataset_alldone_with_largeMCMC195_infoshift_no_weightv13_nosmooth.txt',
#  '/home/bill/next100genes/scaled/ecoM9dataset_alldone_with_largeMCMC194_infoshift_no_weightv13_nosmooth.txt',
#  '/home/bill/next100genes/scaled/hicB0cAMPdataset_alldone_with_largeMCMC195_infoshift_no_weightv13_nosmooth.txt',
#  '/home/bill/next100genes/scaled/hicB0cAMPdataset_alldone_with_largeMCMC195_infoshift_no_weightv15_smoothed.txt',
#  '/home/bill/next100genes/scaled/ecoSSdataset_alldone_with_largeMCMC194_infoshift_no_weightv13_nosmooth.txt',
#  '/home/bill/next100genes/scaled/xapABheatdataset_alldone_with_largeMCMC194_infoshift_no_weightv15_smoothed.txt',
#  '/home/bill/next100genes/scaled/ecoLBdataset_alldone_with_largeMCMC194_infoshift_no_weightv15_smoothed.txt',
#  '/home/bill/next100genes/scaled/xapAB0cAMPdataset_alldone_with_largeMCMC194_infoshift_no_weightv13_nosmooth.txt',
#  '/home/bill/next100genes/scaled/hicBmetaldataset_alldone_with_largeMCMC194_infoshift_no_weightv15_smoothed.txt',
#  '/home/bill/next100genes/scaled/ydhOM9dataset_alldone_with_largeMCMC195_infoshift_no_weightv15_smoothed.txt',
#  '/home/bill/next100genes/scaled/rumBAnaerodataset_alldone_with_largeMCMC195_infoshift_no_weightv15_smoothed.txt',
#  '/home/bill/next100genes/scaled/rumBAnaerodataset_alldone_with_largeMCMC194_infoshift_no_weightv13_nosmooth.txt',
#  '/home/bill/next100genes/scaled/hicBM9dataset_alldone_with_largeMCMC195_infoshift_no_weightv13_nosmooth.txt',
#  '/home/bill/next100genes/scaled/yagHM9dataset_alldone_with_largeMCMC194_infoshift_no_weightv15_smoothed.txt',
#  '/home/bill/next100genes/scaled/xapABLBdataset_alldone_with_largeMCMC195_infoshift_no_weightv15_smoothed.txt',
#  '/home/bill/next100genes/scaled/xapABTredataset_alldone_with_largeMCMC194_infoshift_no_weightv13_nosmooth.txt',
#  '/home/bill/next100genes/scaled/hicB0cAMPdataset_alldone_with_largeMCMC194_infoshift_no_weightv13_nosmooth.txt',
#  '/home/bill/next100genes/scaled/ecoheatdataset_alldone_with_largeMCMC195_infoshift_no_weightv13_nosmooth.txt',
#  '/home/bill/next100genes/scaled/ecoLBdataset_alldone_with_largeMCMC195_infoshift_no_weightv13_nosmooth.txt',
#  '/home/bill/next100genes/scaled/xapABLBdataset_alldone_with_largeMCMC194_infoshift_no_weightv15_smoothed.txt',
#  '/home/bill/next100genes/scaled/yagHLBdataset_alldone_with_largeMCMC195_infoshift_no_weightv15_smoothed.txt',
#  '/home/bill/next100genes/scaled/yagHarabinosedataset_alldone_with_largeMCMC194_infoshift_no_weightv15_smoothed.txt',
#  '/home/bill/next100genes/scaled/marRLBdataset_5759_RNA41_format_MCMC194_infoshift_no_weightv13_nosmooth.txt',
#  '/home/bill/next100genes/scaled/mutMLBdataset_5759_RNA41_with_tagv3_0_160MCMC194_infoshift_no_weightv13_nosmooth.txt',
#  '/home/bill/next100genes/scaled/yagHSSdataset_alldone_with_largeMCMC195_infoshift_no_weightv15_smoothed.txt',
#  '/home/bill/next100genes/scaled/yagHSSdataset_alldone_with_largeMCMC194_infoshift_no_weightv15_smoothed.txt',
#  '/home/bill/next100genes/scaled/yagHAnaerodataset_alldone_with_largeMCMC195_infoshift_no_weightv15_smoothed.txt',
#  '/home/bill/next100genes/scaled/rhledataset_5760_RNA40_with_tagv3_0_160_MCMC194_infoshift_no_weightv15_smoothed.txt',
#  '/home/bill/next100genes/scaled/xapAB0cAMPdataset_alldone_with_largeMCMC195_infoshift_no_weightv15_smoothed.txt',
#  '/home/bill/next100genes/scaled/ecoAnaerodataset_alldone_with_largeMCMC195_infoshift_no_weightv15_smoothed.txt',
#  '/home/bill/next100genes/scaled/hicBM9dataset_alldone_with_largeMCMC194_infoshift_no_weightv13_nosmooth.txt',
#  '/home/bill/next100genes/scaled/hicBxylaradataset_alldone_with_largeMCMC194_infoshift_no_weightv15_smoothed.txt',
#  '/home/bill/next100genes/scaled/tigheatdataset_alldone_with_largeMCMC195_infoshift_no_weightv13_nosmooth.txt',
#  '/home/bill/next100genes/scaled/yagHM9dataset_alldone_with_largeMCMC194_infoshift_no_weightv13_nosmooth.txt',
#  '/home/bill/next100genes/scaled/yagHSSdataset_alldone_with_largeMCMC194_infoshift_no_weightv13_nosmooth.txt',
#  '/home/bill/next100genes/scaled/xapABAnaerodataset_alldone_with_largeMCMC194_infoshift_no_weightv15_smoothed.txt',
#  '/home/bill/next100genes/scaled/hicBM9dataset_alldone_with_largeMCMC194_infoshift_no_weightv15_smoothed.txt',
#  '/home/bill/next100genes/scaled/xapABarabinosedataset_alldone_with_largeMCMC194_infoshift_no_weightv15_smoothed.txt',
#  '/home/bill/next100genes/scaled/ydhOAnaerodataset_alldone_with_largeMCMC195_infoshift_no_weightv15_smoothed.txt',
#  '/home/bill/next100genes/scaled/xapABarabinosedataset_alldone_with_largeMCMC194_infoshift_no_weightv13_nosmooth.txt',
#  '/home/bill/next100genes/scaled/yagHSSdataset_alldone_with_largeMCMC195_infoshift_no_weightv13_nosmooth.txt',
#  '/home/bill/next100genes/scaled/hicBLBdataset_alldone_with_largeMCMC194_infoshift_no_weightv15_smoothed.txt',
#  '/home/bill/next100genes/scaled/xapABM9dataset_alldone_with_largeMCMC194_infoshift_no_weightv15_smoothed.txt',
#  '/home/bill/next100genes/scaled/ecoM9dataset_alldone_with_largeMCMC195_infoshift_no_weightv15_smoothed.txt',
#  '/home/bill/next100genes/scaled/ydhOM9dataset_alldone_with_largeMCMC194_infoshift_no_weightv13_nosmooth.txt',
#  '/home/bill/next100genes/scaled/yagHM9dataset_alldone_with_largeMCMC195_infoshift_no_weightv13_nosmooth.txt',
#  '/home/bill/next100genes/scaled/hicBxylaradataset_alldone_with_largeMCMC194_infoshift_no_weightv13_nosmooth.txt',
#  '/home/bill/next100genes/scaled/ecoxanth2dataset_alldone_with_largeMCMC194_infoshift_no_weightv15_smoothed.txt',
#  '/home/bill/next100genes/scaled/hicBxylaradataset_alldone_with_largeMCMC195_infoshift_no_weightv15_smoothed.txt',
#  '/home/bill/next100genes/scaled/dcmLBdataset_5759_RNA41_with_tagv3_0_160MCMC195_infoshift_no_weightv13_nosmooth.txt',
#  '/home/bill/next100genes/scaled/xapABM9dataset_alldone_with_largeMCMC195_infoshift_no_weightv15_smoothed.txt',
#  '/home/bill/next100genes/scaled/ydhOAnaerodataset_alldone_with_largeMCMC194_infoshift_no_weightv15_smoothed.txt',
#  '/home/bill/next100genes/scaled/xapABarabinosedataset_alldone_with_largeMCMC195_infoshift_no_weightv15_smoothed.txt',
#  '/home/bill/next100genes/scaled/ybjXdataset_5759_RNA41_with_tagv3_0_160_MCMC194_infoshift_no_weightv15_smoothed.txt',
#  '/home/bill/next100genes/scaled/hicBLBdataset_alldone_with_largeMCMC195_infoshift_no_weightv15_smoothed.txt',
#  '/home/bill/next100genes/scaled/hicBxanth2dataset_alldone_with_largeMCMC194_infoshift_no_weightv15_smoothed.txt',
#  '/home/bill/next100genes/scaled/ecoLBdataset_alldone_with_largeMCMC195_infoshift_no_weightv15_smoothed.txt',
#  '/home/bill/next100genes/scaled/ybjXLBdataset_5759_RNA41_with_tagv3_0_160_MCMC194_infoshift_no_weightv16_smoothed.txt',
#  '/home/bill/next100genes/scaled/relM9dataset_5760_RNA40_with_tagv3_0_160_MCMC194_infoshift_no_weightv13_nosmooth.txt',
#  '/home/bill/next100genes/scaled/yagHarabinosedataset_alldone_with_largeMCMC195_infoshift_no_weightv15_smoothed.txt',
#  '/home/bill/next100genes/scaled/hicBheatdataset_alldone_with_largeMCMC194_infoshift_no_weightv15_smoothed.txt']

# %%
alldf_RNAP = pd.io.parsers.read_csv('RNAP/comb_RNAP_sigma.csv')

# %%
def find_RNAP(s):
    '''Identify if a given putative regulatory region contains an RNAP binding site.
    To do this we cross reference the location of the putative binding site with a list of identified
    RNAP sites.'''
    gene = s['gene']
    try:
        RNAP_sites = get_RNAP_sites(alldf_RNAP[alldf_RNAP['gene'] == gene])
    except:
        RNAP_sites = []
    is_RNAP = False
    start = s['start']
    end = s['end']
    for RNAP in RNAP_sites:
        '''Our RNAP sites are listed based on the location of the RNAP minus 35. We check whether that
        or the minus 10 region (which is why we have to possible regions), exist in the region.'''
        if ((start - 2 < RNAP) and (end > RNAP + 5)) or ((start < RNAP + 29) and (end > RNAP + 21)):
            is_RNAP = True    
    return is_RNAP

# %%
def get_RNAP_sites(s):
    '''This function turns the entry in the dataframe of the RNAP sites into a list.'''
    outsites = []
    for i,row in s.iterrows():
        q = row['sites']
        q2 = q.split()
        q3 = [int(x) for x in q2]
        outsites = outsites + q3
    return list(set(outsites))

# %%
#all possible growth conditions.
possible_growths = ['fructose','42','acetate','LB','heat','Anaero','arabinose','xylara','0cAMP','SS','arabionse','metal','Fe','xanth2','M9','Tre','deoR','phoP']

# %%
threshs = [0.00025]

# %%
#we set an averaging size of 15, as this is a typical size for a binding site.
windowsize = 15
def do_sum2(s,length_info=160):
    '''this function does a summation 15 base pairs'''
    outarr = np.zeros(length_info - windowsize)
    for i in range(length_info - windowsize):
        outarr[i] = s[i:(i+windowsize)].sum()
    return outarr


#we define some column names. The only purpose of that these are the columns that are used in 
#the any energy matrices.
val_cols = ['val_A','val_C','val_G','val_T']

for thresh in threshs:
    counter = 0
    outdf = pd.DataFrame(columns=['gene','growth','feat_num','start','end','type'])    
    for name in allnames:
        try:
            noleader = name.split('/')[-1]
            '''parse file name to get gene name'''
            growth = 'false_positive'
            gene = noleader.split('_')[0]
            #load in information footprint
            df = pd.io.parsers.read_csv(name,delim_whitespace=True)
            length_info = len(df['info'])
            em = np.abs(np.array(list(df['info'])))
            em_noabs = np.array(list(df['info']))
            
            #invert information values.
            em_noabs = em_noabs*-1

            #split the information footprint into two groups of repressor like and activator like bases.
            pos_mat = np.zeros(length_info)
            neg_mat = np.zeros(length_info)
            for q in range(len(em_noabs)):
                if em_noabs[q] > 0:
                    pos_mat[q] = np.abs(em_noabs[q])
                else:
                    neg_mat[q] = np.abs(em_noabs[q])

            #sum over 15 base pair windows
            summedarr2 = do_sum2(pos_mat)
            summedarr2_neg = do_sum2(neg_mat)

            #initialize array where we will store whether or not the average outcome beats threshold.
            is_thresh = np.zeros(length_info-windowsize)
            is_thresh_neg = np.zeros(length_info-windowsize)
            for i in range(length_info-windowsize):
                is_thresh[i] = summedarr2[i] > thresh*windowsize
                is_thresh_neg[i] = summedarr2_neg[i] > thresh*windowsize
                is_thresh_neg[i] = is_thresh_neg[i]*-1
    
            outdf_temp = find_region.select_region(is_thresh,gene,growth)
            outdf_temp2 = find_region.select_region(is_thresh_neg,gene,growth)
            for i,row in outdf_temp.iterrows():
                start = row['start']
                end = row['end']
                newstart,newend = find_region.find_edges(pos_mat,start,end)
                outdf.loc[counter,['gene','growth','feat_num','start','end','type']] = [row['gene'],growth,row['feat_num'],newstart,newend,row['type']]
                counter = counter + 1
            for i,row in outdf_temp2.iterrows():
                start = row['start']
                end = row['end']
                newstart,newend = find_region.find_edges(neg_mat,start,end)
                outdf.loc[counter,['gene','growth','feat_num','start','end','type']] = [row['gene'],growth,row['feat_num'],newstart,newend,row['type']]
                counter = counter + 1
        except Exception as e:
            print(e)
        print(gene)
    outdf['RNAP'] = outdf.apply(find_RNAP,axis=1)
    outdf.to_csv('/home/bill/next100genes/false_positive/test_all_features_auto20_for_check_split_' + str(thresh) + '.csv')
    z = find_region.merge_growths(outdf,15)
    z['contains RNAP'] = z.apply(find_RNAP,axis=1)
    z.to_csv('/home/bill/next100genes/false_positive/test_all_features_auto_merged_20_scaled_for_RNAP_check_' + str(thresh) + '.csv')
# Out:
# xapABLBdataset
# yagHAnaerodataset
# xapABTredataset
# hicBxylaradataset
# ydhOheatdataset
# hicBmetaldataset
# hicBxanth2dataset
# hicBLBdataset
# hicBM9dataset
# xapABheatdataset
# hicBmetaldataset
# yagHarabinosedataset
# xapABheatdataset
# rumBAnaerodataset
# xapABM9dataset
# ecoM9dataset
# xapABAnaerodataset
# ydhOM9dataset
# tigM9dataset
# yagHAnaerodataset
# tigM9dataset
# ecoheatdataset
# ydhOheatdataset
# xapABheatdataset
# ydhOAnaerodataset
# ecoFedataset
# yagHLBdataset
# ecoLBdataset
# ecoAnaerodataset
# yagHarabinosedataset
# xapABTredataset
# xapAB0cAMPdataset
# ecometaldataset
# tigM9dataset
# yagHAnaerodataset
# xapABarabinosedataset
# yagHM9dataset
# ydhOAnaerodataset
# tigM9dataset
# hicBheatdataset
# ecoarabinosedataset
# ecoAnaerodataset
# hicBLBdataset
# ecometaldataset
# ecoM9dataset
# ecoheatdataset
# ydhOLBdataset
# hicBheatdataset
# ecoxylaradataset
# yagHheatdataset
# xapABSSdataset
# xapABSSdataset
# hicBTredataset
# ecoheatdataset
# ecoSSdataset
# hicBTredataset
# xapABSSdataset
# hicBxanth2dataset
# ecoxylaradataset
# xapABLBdataset
# rumBAnaerodataset
# amiCdataset
# ecoFedataset
# relM9dataset
# hicBmetaldataset
# hicB0cAMPdataset
# phnAdataset
# rhledataset
# dgoRLB
# tigheatdataset
# ydhOM9dataset
# hicBxanth2dataset
# xapABSSdataset
# yagHheatdataset
# xapABM9dataset
# hicBheatdataset
# ecoxanth2dataset
# ecoAnaerodataset
# ybjXLBdataset
# ecoarabinosedataset
# phnAdataset
# hicBTredataset
# xapABTredataset
# hicBTredataset
# ydhOLBdataset
# xapAB0cAMPdataset
# ecoM9dataset
# hicB0cAMPdataset
# hicB0cAMPdataset
# ecoSSdataset
# xapABheatdataset
# ecoLBdataset
# xapAB0cAMPdataset
# hicBmetaldataset
# ydhOM9dataset
# rumBAnaerodataset
# rumBAnaerodataset
# hicBM9dataset
# yagHM9dataset
# xapABLBdataset
# xapABTredataset
# hicB0cAMPdataset
# ecoheatdataset
# ecoLBdataset
# xapABLBdataset
# yagHLBdataset
# yagHarabinosedataset
# marRLBdataset
# mutMLBdataset
# yagHSSdataset
# yagHSSdataset
# yagHAnaerodataset
# rhledataset
# xapAB0cAMPdataset
# ecoAnaerodataset
# hicBM9dataset
# hicBxylaradataset
# tigheatdataset
# yagHM9dataset
# yagHSSdataset
# xapABAnaerodataset
# hicBM9dataset
# xapABarabinosedataset
# ydhOAnaerodataset
# xapABarabinosedataset
# yagHSSdataset
# hicBLBdataset
# xapABM9dataset
# ecoM9dataset
# ydhOM9dataset
# yagHM9dataset
# hicBxylaradataset
# ecoxanth2dataset
# hicBxylaradataset
# dcmLBdataset
# xapABM9dataset
# ydhOAnaerodataset
# xapABarabinosedataset
# ybjXdataset
# hicBLBdataset
# hicBxanth2dataset
# ecoLBdataset
# ybjXLBdataset
# relM9dataset
# yagHarabinosedataset
# hicBheatdataset
